# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Data Science WorkShop dataset from seaborn
df = pd.read_excel("Data Science WorkShop (Responses) (1).xlsx")
df
# Out:
#                   Timestamp  \
# 0   2025-03-26 16:17:02.116
# 1   2025-03-26 16:18:53.133
# 2   2025-03-26 16:22:28.493
# 3   2025-03-26 16:23:06.405
# 4   2025-03-26 16:26:10.529
# ..                      ...
# 190 2025-03-27 11:38:36.386
# 191 2025-03-27 11:39:17.215
# 192 2025-03-27 11:40:23.702
# 193 2025-03-27 11:40:24.732
# 194 2025-03-27 11:46:58.437
#
#     Age in years (round off to nearest integer).  No Units should be entered. Only the number  \
# 0                                                   21
# 1                                                   37
# 2                                                   20
# 3                                                   24
# 4                                                   21
# ..                                                 ...
# 190                                                 20
# 191                                                 20
# 192                                                 20
# ...

# %%
# Display dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 10 columns):
#  #   Column                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                    --------------  -----
#  0   Timestamp                                                                                                                                 195 non-null    datetime64[ns]
#  1   Age in years (round off to nearest integer).  No Units should be entered. Only the number                                                 195 non-null    object
#  2   Weight (In Kg, round off to nearest integer) No Units should be entered. Only the number                                                  195 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Timestamp',
#        'Age in years (round off to nearest integer).  No Units should be entered. Only the number',
#        'Weight (In Kg, round off to nearest integer) No Units should be entered. Only the number',
#        'Height (In Inches. Round off to nearest integer).  No Units should be entered. Only the number',
#        'Gender',
#        'Write a paragraph on the qualities of a good student. (Minimum 50 words, maximum 100 words)',
#        'Distance between your hometown and college.   (In Kilometer. Round off to nearest integer).  No Units should be entered. Only the number',
#        'Time taken to reach college from your hometown. (In Hours. Round off to nearest integer).  No Units should be entered. Only the number',
#        'District in which your hometown is ',
#        'State in which your hometown is '],
#       dtype='object')

# %%
df.rename(columns={"Age in years (round off to nearest integer).  No Units should be entered. Only the number":"Age"},inplace=True)
df
# Out:
#                   Timestamp Age  \
# 0   2025-03-26 16:17:02.116  21
# 1   2025-03-26 16:18:53.133  37
# 2   2025-03-26 16:22:28.493  20
# 3   2025-03-26 16:23:06.405  24
# 4   2025-03-26 16:26:10.529  21
# ..                      ...  ..
# 190 2025-03-27 11:38:36.386  20
# 191 2025-03-27 11:39:17.215  20
# 192 2025-03-27 11:40:23.702  20
# 193 2025-03-27 11:40:24.732  21
# 194 2025-03-27 11:46:58.437  20
#
#     Weight (In Kg, round off to nearest integer) No Units should be entered. Only the number  \
# 0                                                   60
# 1                                                  101
# 2                                                   65
# 3                                                   69
# 4                                                   65
# ..                                                 ...
# 190                                                 72
# 191                                                 62
# ...

# %%
df.rename(columns={"Weight (In Kg, round off to nearest integer) No Units should be entered. Only the number":"Weight"},inplace=True)
df
# Out:
#                   Timestamp Age Weight  \
# 0   2025-03-26 16:17:02.116  21     60
# 1   2025-03-26 16:18:53.133  37    101
# 2   2025-03-26 16:22:28.493  20     65
# 3   2025-03-26 16:23:06.405  24     69
# 4   2025-03-26 16:26:10.529  21     65
# ..                      ...  ..    ...
# 190 2025-03-27 11:38:36.386  20     72
# 191 2025-03-27 11:39:17.215  20     62
# 192 2025-03-27 11:40:23.702  20     55
# 193 2025-03-27 11:40:24.732  21     55
# 194 2025-03-27 11:46:58.437  20     60
#
#     Height (In Inches. Round off to nearest integer).  No Units should be entered. Only the number  \
# 0                                                  5'3
# 1                                                   70
# 2                                                  5.9
# 3                                                  5.9
# 4                                                  170
# ..                                                 ...
# 190                                              70.86
# ...

# %%
df.rename(columns={"Height (In Inches. Round off to nearest integer).  No Units should be entered. Only the number":"Height"},inplace=True)
df
# Out:
#                   Timestamp Age Weight Height  Gender  \
# 0   2025-03-26 16:17:02.116  21     60    5'3  Female
# 1   2025-03-26 16:18:53.133  37    101     70    Male
# 2   2025-03-26 16:22:28.493  20     65    5.9    Male
# 3   2025-03-26 16:23:06.405  24     69    5.9    Male
# 4   2025-03-26 16:26:10.529  21     65    170    Male
# ..                      ...  ..    ...    ...     ...
# 190 2025-03-27 11:38:36.386  20     72  70.86    Male
# 191 2025-03-27 11:39:17.215  20     62    5.6    Male
# 192 2025-03-27 11:40:23.702  20     55    5.4    Male
# 193 2025-03-27 11:40:24.732  21     55      5    Male
# 194 2025-03-27 11:46:58.437  20     60     65    Male
#
#     Write a paragraph on the qualities of a good student. (Minimum 50 words, maximum 100 words)  \
# 0    A excellent student demonstrates attributes su...
# 1                                                  NaN
# 2    A good student is disciplined, hardworking and...
# ...

# %%
df.rename(columns={"Write a paragraph on the qualities of a good student. (Minimum 50 words, maximum 100 words)":"Qualities of Student"},inplace=True)
df
# Out:
#                   Timestamp Age Weight Height  Gender  \
# 0   2025-03-26 16:17:02.116  21     60    5'3  Female
# 1   2025-03-26 16:18:53.133  37    101     70    Male
# 2   2025-03-26 16:22:28.493  20     65    5.9    Male
# 3   2025-03-26 16:23:06.405  24     69    5.9    Male
# 4   2025-03-26 16:26:10.529  21     65    170    Male
# ..                      ...  ..    ...    ...     ...
# 190 2025-03-27 11:38:36.386  20     72  70.86    Male
# 191 2025-03-27 11:39:17.215  20     62    5.6    Male
# 192 2025-03-27 11:40:23.702  20     55    5.4    Male
# 193 2025-03-27 11:40:24.732  21     55      5    Male
# 194 2025-03-27 11:46:58.437  20     60     65    Male
#
#                                   Qualities of Student  \
# 0    A excellent student demonstrates attributes su...
# 1                                                  NaN
# 2    A good student is disciplined, hardworking and...
# 3    Good students should be disciplined, Attentive...
# ...

# %%
df.rename(columns={'Distance between your hometown and college. (In Kilometer. Round off to nearest integer).  No Units should be entered. Only the number':'Distances in kilometer '},inplace=True)
df
# Out:
#                   Timestamp Age Weight Height  Gender  \
# 0   2025-03-26 16:17:02.116  21     60    5'3  Female
# 1   2025-03-26 16:18:53.133  37    101     70    Male
# 2   2025-03-26 16:22:28.493  20     65    5.9    Male
# 3   2025-03-26 16:23:06.405  24     69    5.9    Male
# 4   2025-03-26 16:26:10.529  21     65    170    Male
# ..                      ...  ..    ...    ...     ...
# 190 2025-03-27 11:38:36.386  20     72  70.86    Male
# 191 2025-03-27 11:39:17.215  20     62    5.6    Male
# 192 2025-03-27 11:40:23.702  20     55    5.4    Male
# 193 2025-03-27 11:40:24.732  21     55      5    Male
# 194 2025-03-27 11:46:58.437  20     60     65    Male
#
#                                   Qualities of Student  \
# 0    A excellent student demonstrates attributes su...
# 1                                                  NaN
# 2    A good student is disciplined, hardworking and...
# 3    Good students should be disciplined, Attentive...
# ...

# %%
df.rename(columns={"Time taken to reach college from your hometown. (In Hours. Round off to nearest integer).  No Units should be entered. Only the number":"Time taken to reach"},inplace=True)
df
# Out:
#                   Timestamp Age Weight Height  Gender  \
# 0   2025-03-26 16:17:02.116  21     60    5'3  Female
# 1   2025-03-26 16:18:53.133  37    101     70    Male
# 2   2025-03-26 16:22:28.493  20     65    5.9    Male
# 3   2025-03-26 16:23:06.405  24     69    5.9    Male
# 4   2025-03-26 16:26:10.529  21     65    170    Male
# ..                      ...  ..    ...    ...     ...
# 190 2025-03-27 11:38:36.386  20     72  70.86    Male
# 191 2025-03-27 11:39:17.215  20     62    5.6    Male
# 192 2025-03-27 11:40:23.702  20     55    5.4    Male
# 193 2025-03-27 11:40:24.732  21     55      5    Male
# 194 2025-03-27 11:46:58.437  20     60     65    Male
#
#                                   Qualities of Student  \
# 0    A excellent student demonstrates attributes su...
# 1                                                  NaN
# 2    A good student is disciplined, hardworking and...
# 3    Good students should be disciplined, Attentive...
# ...

# %%
# age_column = "Age"

df["Age"] = pd.to_numeric(df["Age"], errors='coerce')
# df
df = df[(df["Age"] >= 0) & (df["Age"] <= 100)]


ages = df["Age"].dropna()
ages
# Out:
# 0      21.0
# 1      37.0
# 2      20.0
# 3      24.0
# 4      21.0
#        ...
# 190    20.0
# 191    20.0
# 192    20.0
# 193    21.0
# 194    20.0
# Name: Age, Length: 187, dtype: float64

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Weight', 'Height', 'Gender',
#        'Qualities of Student',
#        'Distance between your hometown and college.   (In Kilometer. Round off to nearest integer).  No Units should be entered. Only the number',
#        'Time taken to reach', 'District in which your hometown is ',
#        'State in which your hometown is '],
#       dtype='object')

# %%
df.rename(columns={'Distance between your hometown and college.   (In Kilometer. Round off to nearest integer).  No Units should be entered. Only the number':'Distance covered(KM)'},inplace=True)
df
# Out:
# C:\Users\mmamt\AppData\Local\Temp\ipykernel_106524\1811245680.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Distance between your hometown and college.   (In Kilometer. Round off to nearest integer).  No Units should be entered. Only the number':'Distance covered(KM)'},inplace=True)
#                   Timestamp   Age Weight Height  Gender  \
# 0   2025-03-26 16:17:02.116  21.0     60    5'3  Female
# 1   2025-03-26 16:18:53.133  37.0    101     70    Male
# 2   2025-03-26 16:22:28.493  20.0     65    5.9    Male
# 3   2025-03-26 16:23:06.405  24.0     69    5.9    Male
# 4   2025-03-26 16:26:10.529  21.0     65    170    Male
# ..                      ...   ...    ...    ...     ...
# 190 2025-03-27 11:38:36.386  20.0     72  70.86    Male
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Weight', 'Height', 'Gender',
#        'Qualities of Student', 'Distance covered(KM)', 'Time taken to reach',
#        'District in which your hometown is ',
#        'State in which your hometown is '],
#       dtype='object')

# %%
df.rename(columns={'District in which your hometown is ':'Hometown_district'},inplace=True)
df
# Out:
# C:\Users\mmamt\AppData\Local\Temp\ipykernel_106524\233416070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'District in which your hometown is ':'Hometown_district'},inplace=True)
#                   Timestamp   Age Weight Height  Gender  \
# 0   2025-03-26 16:17:02.116  21.0     60    5'3  Female
# 1   2025-03-26 16:18:53.133  37.0    101     70    Male
# 2   2025-03-26 16:22:28.493  20.0     65    5.9    Male
# 3   2025-03-26 16:23:06.405  24.0     69    5.9    Male
# 4   2025-03-26 16:26:10.529  21.0     65    170    Male
# ..                      ...   ...    ...    ...     ...
# 190 2025-03-27 11:38:36.386  20.0     72  70.86    Male
# 191 2025-03-27 11:39:17.215  20.0     62    5.6    Male
# 192 2025-03-27 11:40:23.702  20.0     55    5.4    Male
# ...

# %%
df.rename(columns={'State in which your hometown is ':'Hometown_state'},inplace=True)
df
# Out:
# C:\Users\mmamt\AppData\Local\Temp\ipykernel_106524\4237377990.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'State in which your hometown is ':'Hometown_state'},inplace=True)
#                   Timestamp   Age Weight Height  Gender  \
# 0   2025-03-26 16:17:02.116  21.0     60    5'3  Female
# 1   2025-03-26 16:18:53.133  37.0    101     70    Male
# 2   2025-03-26 16:22:28.493  20.0     65    5.9    Male
# 3   2025-03-26 16:23:06.405  24.0     69    5.9    Male
# 4   2025-03-26 16:26:10.529  21.0     65    170    Male
# ..                      ...   ...    ...    ...     ...
# 190 2025-03-27 11:38:36.386  20.0     72  70.86    Male
# 191 2025-03-27 11:39:17.215  20.0     62    5.6    Male
# 192 2025-03-27 11:40:23.702  20.0     55    5.4    Male
# ...

# %%
df.dropna(how='any', axis=0 ,inplace=True)

display(df)
# Out:
# C:\Users\mmamt\AppData\Local\Temp\ipykernel_106524\1113694162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(how='any', axis=0 ,inplace=True)
#                   Timestamp   Age Weight Height  Gender  \
# 0   2025-03-26 16:17:02.116  21.0     60    5'3  Female
# 2   2025-03-26 16:22:28.493  20.0     65    5.9    Male
# 3   2025-03-26 16:23:06.405  24.0     69    5.9    Male
# 4   2025-03-26 16:26:10.529  21.0     65    170    Male
# 5   2025-03-26 16:26:28.272  20.0     80     66    Male
# ..                      ...   ...    ...    ...     ...
# 190 2025-03-27 11:38:36.386  20.0     72  70.86    Male
# 191 2025-03-27 11:39:17.215  20.0     62    5.6    Male
# 192 2025-03-27 11:40:23.702  20.0     55    5.4    Male
# 193 2025-03-27 11:40:24.732  21.0     55      5    Male
# ...

# %%
df["Height"] = pd.to_numeric(df["Height"], errors='coerce')
df
# Out:
# C:\Users\mmamt\AppData\Local\Temp\ipykernel_106524\961051645.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Height"] = pd.to_numeric(df["Height"], errors='coerce')
#                   Timestamp   Age Weight  Height  Gender  \
# 0   2025-03-26 16:17:02.116  21.0     60     NaN  Female
# 2   2025-03-26 16:22:28.493  20.0     65    5.90    Male
# 3   2025-03-26 16:23:06.405  24.0     69    5.90    Male
# 4   2025-03-26 16:26:10.529  21.0     65  170.00    Male
# 5   2025-03-26 16:26:28.272  20.0     80   66.00    Male
# ..                      ...   ...    ...     ...     ...
# 190 2025-03-27 11:38:36.386  20.0     72   70.86    Male
# 191 2025-03-27 11:39:17.215  20.0     62    5.60    Male
# ...

# %%
df['Distance covered(KM)'] = pd.to_numeric(df['Distance covered(KM)'], errors='coerce') 
df['Time taken to reach'] = pd.to_numeric(df['Time taken to reach'], errors='coerce') 
df 
df
# Out:
# C:\Users\mmamt\AppData\Local\Temp\ipykernel_106524\2722097043.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Distance covered(KM)'] = pd.to_numeric(df['Distance covered(KM)'], errors='coerce')
# C:\Users\mmamt\AppData\Local\Temp\ipykernel_106524\2722097043.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time taken to reach'] = pd.to_numeric(df['Time taken to reach'], errors='coerce')
#                   Timestamp   Age Weight  Height  Gender  \
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                0
# Age                      0
# Weight                   0
# Height                  35
# Gender                   0
# Qualities of Student     0
# Distance covered(KM)    25
# Time taken to reach     34
# Hometown_district        0
# Hometown_state           0
# dtype: int64

# %%
df.dropna(how='any', axis=0 ,inplace=True)

display(df)
# Out:
# C:\Users\mmamt\AppData\Local\Temp\ipykernel_106524\1290018652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(how='any', axis=0 ,inplace=True)
#                   Timestamp   Age Weight  Height  Gender  \
# 5   2025-03-26 16:26:28.272  20.0     80   66.00    Male
# 9   2025-03-26 16:31:37.061  20.0     55    6.00    Male
# 13  2025-03-26 16:44:14.732  20.0     74   70.00    Male
# 16  2025-03-26 16:52:50.137  21.0     48   68.30    Male
# 17  2025-03-26 17:08:25.822  38.0     70    5.00  Female
# ..                      ...   ...    ...     ...     ...
# 190 2025-03-27 11:38:36.386  20.0     72   70.86    Male
# 191 2025-03-27 11:39:17.215  20.0     62    5.60    Male
# 192 2025-03-27 11:40:23.702  20.0     55    5.40    Male
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp               0
# Age                     0
# Weight                  0
# Height                  0
# Gender                  0
# Qualities of Student    0
# Distance covered(KM)    0
# Time taken to reach     0
# Hometown_district       0
# Hometown_state          0
# dtype: int64

# %%
display(df)
# Out:
#                   Timestamp   Age Weight  Height  Gender  \
# 5   2025-03-26 16:26:28.272  20.0     80   66.00    Male
# 9   2025-03-26 16:31:37.061  20.0     55    6.00    Male
# 13  2025-03-26 16:44:14.732  20.0     74   70.00    Male
# 16  2025-03-26 16:52:50.137  21.0     48   68.30    Male
# 17  2025-03-26 17:08:25.822  38.0     70    5.00  Female
# ..                      ...   ...    ...     ...     ...
# 190 2025-03-27 11:38:36.386  20.0     72   70.86    Male
# 191 2025-03-27 11:39:17.215  20.0     62    5.60    Male
# 192 2025-03-27 11:40:23.702  20.0     55    5.40    Male
# 193 2025-03-27 11:40:24.732  21.0     55    5.00    Male
# 194 2025-03-27 11:46:58.437  20.0     60   65.00    Male
#
#                                   Qualities of Student  Distance covered(KM)  \
# 5    A good student must have discipline in their l...                1000.0
# 9    A good student possesses qualities such as dis...                1600.0
# ...

# %%
df.describe()
# Out:
#                            Timestamp        Age      Height  \
# count                             97  97.000000   97.000000
# mean      2025-03-27 07:08:43.152928  20.546392   53.663196
# min       2025-03-26 16:26:28.272000  18.000000    1.580000
# 25%    2025-03-27 07:26:39.307000064  20.000000    5.700000
# 50%    2025-03-27 11:03:35.391000064  20.000000   65.000000
# 75%    2025-03-27 11:06:53.119000064  21.000000   70.000000
# max       2025-03-27 11:46:58.437000  42.000000  175.000000
# std                              NaN   3.016519   41.157951
#
#        Distance covered(KM)  Time taken to reach
# count             97.000000            97.000000
# mean             474.125773            25.733608
# min                0.000000             0.000000
# 25%               20.000000             3.000000
# 50%              280.000000            10.000000
# 75%              950.000000            24.000000
# max             2200.000000          1278.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 97 entries, 5 to 194
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Timestamp             97 non-null     datetime64[ns]
#  1   Age                   97 non-null     float64
#  2   Weight                97 non-null     object
#  3   Height                97 non-null     float64
#  4   Gender                97 non-null     object
#  5   Qualities of Student  97 non-null     object
#  6   Distance covered(KM)  97 non-null     float64
#  7   Time taken to reach   97 non-null     float64
#  8   Hometown_district     97 non-null     object
#  9   Hometown_state        97 non-null     object
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 8.3+ KB

# %%
df.groupby ('Gender')[['Height','Weight']].mean()
# Out:
#            Height     Weight
# Gender
# Female  48.122143  50.928571
# Male    54.597831       61.9

# %%
df.groupby ('Gender')['Age'].agg(['min','max'])
# Out:
#          min   max
# Gender
# Female  19.0  38.0
# Male    18.0  42.0

# %%
df.groupby('Hometown_district')['Distance covered(KM)'].mean().head(10)
# Out:
# Hometown_district
# 1200                          4.0
# Anuppur                     345.0
# Arungabad                   800.0
# Arwal                      1100.0
# Aurangabad                  600.0
# Balod                        65.0
# Baloda bazar                146.0
# Bastar                      350.0
# Bemetara                     35.0
# Bettiah,west champaran     1000.0
# Name: Distance covered(KM), dtype: float64

# %%
df.groupby('Hometown_state')['Distance covered(KM)'].mean().head(10)
# Out:
# Hometown_state
#  Chhattisgarh      220.000000
# BIHAR             1047.000000
# Bihar              954.294118
# Bihar             1152.938462
# C.G                  7.000000
# Cg                 100.000000
# Chattisgarh         59.000000
# Chhatisgarh        350.000000
# Chhattisgarh        92.076923
# Chhattisgarh       154.645161
# Name: Distance covered(KM), dtype: float64

# %%
df.groupby('Hometown_state')['Hometown_district'].unique()
# Out:
# Hometown_state
#  Chhattisgarh                                                [Sakti]
# BIHAR                                                       [Purnea]
# Bihar              [Patna, Sitamarhi, Khagaria , West champaran ,...
# Bihar              [Siwan, Sitamarhi , Jehanabad , Muzaffarpur , ...
# C.G                                                          [Durg ]
# Cg                                                    [Rajnandgaon ]
# Chattisgarh            [Durg, Raipur , Kanker , Dhamdha , Bemetara ]
# Chhatisgarh                                                 [Bastar]
# Chhattisgarh       [Manendragarh, Durg, Baloda bazar, Dhamtari, K...
# Chhattisgarh       [Korba, Durg, Raigarh , Kondagaon , Kabeerdham...
# Chhattishgarh                                                 [Durg]
# Jharkhand                                                   [Ranchi]
# Jharkhand          [West Singhbhum , Bokaro, Chatra , Saraikela -...
# ...

# %%
df.loc[:,'Hometown_state']=df.loc[:,'Hometown_state'].str.strip().str.lower()
df.loc[:,'Hometown_state']=df.loc[:,'Hometown_state'].replace({
    'chattisgarh': 'Chhattisgarh',  
    'chhatisgarh': 'Chhattisgarh',  
    'chhattishgarh': 'Chhattisgarh',  
    'madhyapradesh': 'Madhya Pradesh',  
    'c.g': 'Chhattisgarh',  
    'cg': 'Chhattisgarh',  
    'uttar pradesh': 'Uttar Pradesh',  
    'biha': 'Bihar',  
    'bihar': 'Bihar',  
    'uttar pradesh': 'Uttar Pradesh' 
})  
df
# Out:
#                   Timestamp   Age Weight  Height  Gender  \
# 5   2025-03-26 16:26:28.272  20.0     80   66.00    Male
# 9   2025-03-26 16:31:37.061  20.0     55    6.00    Male
# 13  2025-03-26 16:44:14.732  20.0     74   70.00    Male
# 16  2025-03-26 16:52:50.137  21.0     48   68.30    Male
# 17  2025-03-26 17:08:25.822  38.0     70    5.00  Female
# ..                      ...   ...    ...     ...     ...
# 190 2025-03-27 11:38:36.386  20.0     72   70.86    Male
# 191 2025-03-27 11:39:17.215  20.0     62    5.60    Male
# 192 2025-03-27 11:40:23.702  20.0     55    5.40    Male
# 193 2025-03-27 11:40:24.732  21.0     55    5.00    Male
# 194 2025-03-27 11:46:58.437  20.0     60   65.00    Male
#
#                                   Qualities of Student  Distance covered(KM)  \
# 5    A good student must have discipline in their l...                1000.0
# 9    A good student possesses qualities such as dis...                1600.0
# ...

# %%
grouped_df = df['Hometown_state'].value_counts()
grouped_df
# Out:
# Hometown_state
# chhattisgarh      45
# Bihar             31
# Chhattisgarh       9
# jharkhand          6
# Uttar Pradesh      3
# madhya pradesh     2
# Madhya Pradesh     1
# Name: count, dtype: int64

# %%
df.columns
df
# Out:
#                   Timestamp   Age Weight  Height  Gender  \
# 5   2025-03-26 16:26:28.272  20.0     80   66.00    Male
# 9   2025-03-26 16:31:37.061  20.0     55    6.00    Male
# 13  2025-03-26 16:44:14.732  20.0     74   70.00    Male
# 16  2025-03-26 16:52:50.137  21.0     48   68.30    Male
# 17  2025-03-26 17:08:25.822  38.0     70    5.00  Female
# ..                      ...   ...    ...     ...     ...
# 190 2025-03-27 11:38:36.386  20.0     72   70.86    Male
# 191 2025-03-27 11:39:17.215  20.0     62    5.60    Male
# 192 2025-03-27 11:40:23.702  20.0     55    5.40    Male
# 193 2025-03-27 11:40:24.732  21.0     55    5.00    Male
# 194 2025-03-27 11:46:58.437  20.0     60   65.00    Male
#
#                                   Qualities of Student  Distance covered(KM)  \
# 5    A good student must have discipline in their l...                1000.0
# 9    A good student possesses qualities such as dis...                1600.0
# ...

# %%
plt.figure(figsize=(10,6),facecolor='lightgray')
plt.stem(df["Age"], basefmt="black",orientation="vertical")
plt.legend("Gender")
df.head(10)
plt.show()

# %% [markdown]
# The above  Stem charts Conclude that it visualizes the distribution of ages in the dataset. It provides a clear view of how ages are spread among the respondents, highlighting any clusters or gaps. This helps in quickly identifying the most common age groups and any outliers present in the data.

# %%
plt.figure(figsize=(10, 6))

bin_edges = np.arange(ages.min(), ages.max() + 1)
plt.hist(ages, bins=bin_edges, edgecolor='black', alpha=1)
#sns.set_style(style="darkgrid")
sns.set_style(style="ticks")

#  Labels and title
plt.xlabel("Age")
plt.ylabel("Frequency")
#plt.legend("Gender")
plt.title("Age Distribution Histogram")
# # # # Show the plot
plt.show()

# %% [markdown]
# In the above  histogram chart  conclude that the majority of respondents are in the age group of 20 to 21 years, with very few participants above 30. This indicates that the dataset mainly consists of young adults, likely students, with a small number of older individuals.

# %%
df
# Out:
#                   Timestamp   Age Weight  Height  Gender  \
# 5   2025-03-26 16:26:28.272  20.0     80   66.00    Male
# 9   2025-03-26 16:31:37.061  20.0     55    6.00    Male
# 13  2025-03-26 16:44:14.732  20.0     74   70.00    Male
# 16  2025-03-26 16:52:50.137  21.0     48   68.30    Male
# 17  2025-03-26 17:08:25.822  38.0     70    5.00  Female
# ..                      ...   ...    ...     ...     ...
# 190 2025-03-27 11:38:36.386  20.0     72   70.86    Male
# 191 2025-03-27 11:39:17.215  20.0     62    5.60    Male
# 192 2025-03-27 11:40:23.702  20.0     55    5.40    Male
# 193 2025-03-27 11:40:24.732  21.0     55    5.00    Male
# 194 2025-03-27 11:46:58.437  20.0     60   65.00    Male
#
#                                   Qualities of Student  Distance covered(KM)  \
# 5    A good student must have discipline in their l...                1000.0
# 9    A good student possesses qualities such as dis...                1600.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(9, 6), facecolor='lightblue')
sns.barplot(df,x="Age",y="Height",hue="Gender") 
plt.legend(loc=1)
plt.show()R

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.figure(figsize=(6,5))


df["Gender"].value_counts().plot(kind= "pie",autopct='%0.2f%%')
plt.legend()
plt.title("Gender Proportion")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


plt.figure(figsize=(8,5),facecolor="lightgray")
sns.countplot(df,x="Gender")
plt.title("Gender proportion")

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.figure(figsize=(11,5))
sns.swarmplot(df,x="Hometown_state",y="Weight",hue="Gender",dodge=True)
plt.show()

# %% [markdown]
# The swarm chart provides a clear visualization of the distribution of weights across different hometown states, separated by gender. It highlights the spread and clustering of weight values for each state and shows any noticeable differences between male and female respondents. This helps in identifying patterns or outliers in the weight data among students from various regions.

# %%
group=df.groupby("Hometown_state").agg({ "Distance covered(KM)":"sum"})
plt.figure(figsize=(10,5),facecolor="lightblue")
plt.step(group.index, group["Distance covered(KM)"], where="mid", marker="o")
plt.show()

# %% [markdown]
# In the above step chart  conclude that  the total distance covered by respondents from each hometown state. It highlights which states have students traveling longer distances to reach the college, helping to identify regions with higher or lower travel requirements among the participants.

# %%
group=df.groupby("Hometown_state").agg({ "Age":"sum","Height":"sum"})
#print(group)
plt.figure(figsize=(10,5),facecolor="lightblue")

plt.stackplot(group.index,group["Age"],group["Height"])
#plt.legend()
plt.show()

# %% [markdown]
# The above  stackplot chart  conclude that the combined totals of age and height for each hometown state. It visually demonstrates how these two variables contribute to the overall sum for each state, allowing us to compare the relative distribution of age and height among respondents from different regions.

# %%
plt.figure(figsize=(7, 6), facecolor='silver')
sns.heatmap(df[["Age", "Weight", "Height", "Distance covered(KM)", "Time taken to reach"]].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# The  above correlation heatmap conclude that how different numerical features in the dataset are related to each other. Strong positive or negative values indicate a strong relationship, while values close to zero show little or no relationship. For example, if Age and Height have a high correlation, it means as age increases, height tends to increase as well. This visualization helps quickly identify which variables are closely linked in the dataset.

# %%
plt.figure(figsize=(10,6),facecolor="silver")
sns.boxplot(df,x="Hometown_state",y="Distance covered(KM)",hue="Gender")
plt.title("State distribution by Distance covered")
plt.show()

# %% [markdown]
# The above boxplot shows how the distance covered by students to reach college varies across different states and between genders. It helps us see which states have students traveling longer or shorter distances, and if there are any differences between male and female students in each state.

# %%
plt.figure(figsize=(9,6),facecolor='lightblue')
sns.violinplot(df,x="Height")
plt.title("Height Assumption")
plt.show()

# %% [markdown]
# The above violin plot shows the distribution of heights among all respondents. It illustrates the range, most common height values, and any variations or outliers in the data. The wider sections of the plot indicate where most students' heights are concentrated, while the thinner parts show less common heights.

# %%
plt.figure(figsize=(9,6),facecolor="silver")
sns.boxplot(df,x="Gender",y="Age")
plt.title("Age distribution by Gender")
plt.show()

# %% [markdown]
# The boxplot above shows that the distance students travel to college varies by state and gender. Some states have students who travel much farther than others, and there are differences between male and female students in how far they travel. This helps us see which groups have longer or shorter journeys to college.

# %%
plt.figure(figsize=(9,7),facecolor="silver")
sns.pairplot(df,hue="Gender")
plt.show()

# %% [markdown]
# The above pairplot shows the relationships between different features in the dataset, separated by gender. It helps us see how variables like age, height, weight, distance covered, and time taken to reach college are related to each other for male and female students. Patterns or clusters in the plots can reveal trends or differences between genders in these features.

# %%
plt.figure(figsize=(11,6),facecolor="lightblue")
sns.histplot(df,x="Hometown_state",hue="Gender",kde="True")
plt.title("State distribution by Gender")
plt.show()

# %% [markdown]
# The above histplot shows how students from different states are distributed by gender. It helps us see which states have more male or female students and highlights any differences in the number of students from each state based on gender.

# %% [markdown]
# Overall Conclusion:-
#
# * The abive Data science Workdhop(Responses)  dataset provides insights into the demographic and physical characteristics of students, including their age, gender, height, weight, and travel details to college.
# * Most respondents are young adults, primarily in their early twenties, with a balanced gender distribution.
# * The data shows variation in height and weight across genders and regions. Students come from various states and districts, with some traveling significant distances to attend college.
# * The visualizations highlight patterns such as the concentration of students from certain states, differences in travel distance by gender and region, and relationships between age, height, and weight.
# * Overall, the dataset reflects a diverse student population with varying backgrounds and travel experiences.
